# %% [markdown]
# <a href="https://colab.research.google.com/github/devadethan452/ICT.DSA.DEVADETH/blob/main/ASSIGNMENT_PYTHON_DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
#[1]READ THE DATASET INTO PYTHON ENVIRONMENT

data = pd.read_excel('/content/iris.xls')
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#[2] DISPLAY THE COLUMNS IN THE DATASET

data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#[3] CALCULATE THE MEAN OF EACH COLUMN OF THE DATASET

data['SL'].mean()
# Out:
# 5.843333333333334

# %%
data['SW'].mean()
# Out:
# 3.0540000000000003

# %%
data['PL'].mean()
# Out:
# 3.758666666666666

# %%
data['PW'].mean()
# Out:
# 1.1986666666666668

# %%
#[4]  CHECK FOR THE NULL VALUES PRESENT IN THE DATASET

data.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
#[5]  PERFORM MEANINGFUL VISUALIZATIONS USING THE DATASET. BRING ATLEAST 3 MEANINGFUL VISUALIZATIONS.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.sample(10)
# Out:
#       SL   SW   PL   PW   Classification
# 140  6.7  3.1  5.6  2.4   Iris-virginica
# 21   5.1  3.7  1.5  0.4      Iris-setosa
# 105  7.6  3.0  6.6  2.1   Iris-virginica
# 131  7.9  3.8  6.4  2.0   Iris-virginica
# 31   5.4  3.4  1.5  0.4      Iris-setosa
# 40   5.0  3.5  1.3  0.3      Iris-setosa
# 51   6.4  3.2  4.5  1.5  Iris-versicolor
# 53   5.5  2.3  4.0  1.3  Iris-versicolor
# 144  6.7  3.3  5.7  2.5   Iris-virginica
# 82   5.8  2.7  3.9  1.2  Iris-versicolor

# %%
data.shape
# Out:
# (150, 5)
